# %% [markdown]
# # Importing Data in Python (Part 2)

# %% [markdown]
# <font size="3">
#
# - Quick recap
# - Flat files
#     - text files
# - JavaScript Object Notation (JSON)
# - Importing data from the Web
# - Working with relational databases in Python
# - Importing data from statistical software packages
# - Q&A
#
#
# </font>

# %%
#Libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ### JavaScript Object Notation (JSON)

# %%
df_from_json = pd.read_json("data/stocks.json")

# https://pandas.pydata.org/docs/reference/api/pandas.read_json.html

df_from_json.head()
# Out:
#         Date   Open   High    Low  Close   Volume  Adj Close
# 0 2014-07-21  83.46  83.53  81.81  81.93  2359300      81.93
# 1 2014-07-18  83.30  83.40  82.52  83.35  4020800      83.35
# 2 2014-07-17  84.35  84.63  83.33  83.63  1974000      83.63
# 3 2014-07-16  83.77  84.91  83.66  84.91  1755600      84.91
# 4 2014-07-15  84.30  84.38  83.20  83.58  1874700      83.58

# %% [markdown]
# ## Importing data from the Web

# %%
# Import package
from urllib.request import urlretrieve

# Import pandas
import pandas as pd

# Assign url of file: url
url = 'https://raw.githubusercontent.com/iacenter/CienciaDatos_Python/main/data/winequality-red.csv'

# Save file locally
urlretrieve(url, 'winequality-red.csv')

# Read file into a DataFrame and print its head
df = pd.read_csv('winequality-red.csv', sep=';')

df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %% [markdown]
# ### Opening and reading flat files from the web

# %%
# Import packages
import matplotlib.pyplot as plt
import pandas as pd

# Assign url of file: url
url = 'https://raw.githubusercontent.com/iacenter/CienciaDatos_Python/main/data/winequality-red.csv'

# Read file into a DataFrame: df
df = pd.read_csv(url, sep=';')

# Print the head of the DataFrame
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %% [markdown]
# ### Importing non-flat files from the web

# %%
# Import package
import pandas as pd

# Assign url of file: url
url = 'https://raw.githubusercontent.com/iacenter/CienciaDatos_Python/main/data/latitude.xls'

# Read in all sheets of Excel file: xl
xl = pd.read_excel(url, sheet_name=None)

# Print the sheetnames 
print(xl.keys())

# Print the head of the first sheet (using its name, NOT its index)
print(xl['1700'].head())
# Out:
# dict_keys(['1700', '1900'])
#                  country       1700
# 0            Afghanistan  34.565000
# 1  Akrotiri and Dhekelia  34.616667
# 2                Albania  41.312000
# 3                Algeria  36.720000
# 4         American Samoa -14.307000

# %%
# Import package
import pandas as pd

# Assign url of file: url
url = 'https://raw.githubusercontent.com/iacenter/CienciaDatos_Python/main/data/urbanpop.xlsx'

# Read in all sheets of Excel file: xl
xl = pd.read_excel(url, sheet_name="1960-1966")

# Print the head of the first sheet 
xl.head()
# Out:
#           country       1960          1961          1962          1963  \
# 0     Afghanistan   769308.0  8.149230e+05  8.585217e+05  9.039139e+05
# 1         Albania   494443.0  5.118028e+05  5.294389e+05  5.473767e+05
# 2         Algeria  3293999.0  3.515148e+06  3.739963e+06  3.973289e+06
# 3  American Samoa        NaN  1.366030e+04  1.416580e+04  1.475893e+04
# 4         Andorra        NaN  8.723921e+03  9.700346e+03  1.074838e+04
#
#            1964          1965          1966
# 0  9.512259e+05  1.000582e+06  1.058743e+06
# 1  5.655718e+05  5.839829e+05  6.025122e+05
# 2  4.220987e+06  4.488176e+06  4.649105e+06
# 3  1.539642e+04  1.604482e+04  1.669311e+04
# 4  1.186586e+04  1.305275e+04  1.421681e+04

# %%
# Import package
import pandas as pd

# Assign url of file: url
url = 'https://raw.githubusercontent.com/iacenter/CienciaDatos_Python/main/data/stocks.json'

# Read in all sheets of Excel file: xl
df_from_json = pd.read_json(url)

df_from_json.head()
# Out:
#         Date   Open   High    Low  Close   Volume  Adj Close
# 0 2014-07-21  83.46  83.53  81.81  81.93  2359300      81.93
# 1 2014-07-18  83.30  83.40  82.52  83.35  4020800      83.35
# 2 2014-07-17  84.35  84.63  83.33  83.63  1974000      83.63
# 3 2014-07-16  83.77  84.91  83.66  84.91  1755600      84.91
# 4 2014-07-15  84.30  84.38  83.20  83.58  1874700      83.58

# %% [markdown]
# ### INEGI
#
# API del Banco de Indicadores
#
# <https://www.inegi.org.mx/servicios/api_indicadores.html>
#
#     - Token
# <https://www.inegi.org.mx/app/api/indicadores/interna_v1_1/tokenVerify.aspx>

# %%
import requests
import json

#Llamado al API
url='https://www.inegi.org.mx/app/api/indicadores/desarrolladores/jsonxml/INDICATOR/1002000002/es/00000/false/BISE/2.0/da4aa7d3-e5a5-e0cf-7358-c1986f9bc930?type=json'
response= requests.get(url)

if response.status_code==200:
    content= json.loads(response.content)
    
#content

# %% [markdown]
# ### The Worl Bank
#
# Developer Information
#
# <https://datahelpdesk.worldbank.org/knowledgebase/topics/125589>
#
# WBGAPI
#
# <https://pypi.org/project/wbgapi/>

# %% [markdown]
# Here is a basic data query that returns a single indicator for all available economies and 5 even years.

# %%
import wbgapi as wb   
import pandas as pd   
import matplotlib.pyplot as plt

wb.data.DataFrame('SP.POP.TOTL', time=range(2010, 2020, 2), labels=True)
# Out:
#                                 Country       YR2010       YR2012  \
# economy
# ZWE                            Zimbabwe   12697728.0   13115149.0
# ZMB                              Zambia   13605986.0   14465148.0
# YEM                         Yemen, Rep.   23154854.0   24473176.0
# PSE                  West Bank and Gaza    3786161.0    3979998.0
# VIR               Virgin Islands (U.S.)     108357.0     108188.0
# ...                                 ...          ...          ...
# CEB      Central Europe and the Baltics  104421447.0  103935318.0
# CSS              Caribbean small states    6973193.0    7072640.0
# ARB                          Arab World  354890097.0  371437642.0
# AFW          Africa Western and Central  350556886.0  370243017.0
# AFE         Africa Eastern and Southern  518468229.0  547482863.0
#
#               YR2014       YR2016       YR2018
# economy
# ZWE       13586710.0   14030338.0   14438812.0
# ZMB       15399793.0   16363449.0   17351714.0
# YEM       25823488.0   27168210.0   28498683.0
# PSE        4173398.0    4367088.0    4569087.0
# VIR         107882.0     107516.0     107001.0
# ...              ...          ...          ...
# CEB      103496179.0  102994278.0  102538451.0
# CSS        7173443.0    7269385.0    7358929.0
# ARB      387899835.0  404042892.0  419851989.0
# AFW      390882979.0  412551299.0  435229381.0
# AFE      578075373.0  609978946.0  643090131.0
#
# [266 rows x 6 columns]

# %% [markdown]
# Here is a plot of per-capita income for 2 countries and 2 decades:

# %%
wb.data.DataFrame('NY.GDP.PCAP.CD', [  'MEX', 'COL'],
                  range(2000, 2021), index='time').plot(figsize=(10, 6))
plt.show()

# %% [markdown]
# ### Datos Abiertos
#
# México
#
# <https://datos.gob.mx/>

# %%
import requests
import json

#Llamado al API
url='https://api.datos.gob.mx/v1/api-catalog'
response= requests.get(url)

if response.status_code==200:
    content= json.loads(response.content)
    
content
# Out:
# {'pagination': {'pageSize': 100, 'page': 1, 'total': 342},
#  'results': [{'_id': '5cccf090e2705c193281f0aa',
#    'variables': ['_id', 'ocid', 'releases', 'compiledRelease'],
#    'count': 300265,
#    'url': 'https://api.datos.gob.mx/v2/Records',
#    'endpoint': 'Records'},
#   {'_id': '5cccf090e2705c193281f0ab',
#    'variables': ['_id',
#     'date',
#     'initiationType',
#     'cycle',
#     'publisher',
#     'tender',
#     'contracts',
#     'parties',
#     'ocid',
#     'language',
#     'id',
#     'tag',
#     'buyer',
#     'awards'],
#    'count': 292289,
#    'url': 'https://api.datos.gob.mx/v2/Releases_SFP',
#    'endpoint': 'Releases_SFP'},
#   {'_id': '5cccf090e2705c193281f0ac',
#    'variables': ['_id',
#     'sad',
#     'date-insert',
#     'sa',
#     'degradacion-fisica',
#     'degradacion-quimica',
#     'sn',
#     'periodo',
#     'erosion-eolica',
#     'erosion-hidrica'],
#    'count': 1,
#    'url': 'https://api.datos.gob.mx/v2/SNEDH-001f6b0f-bb9e-4b81-956d-ceab7f87b13c',
#    'endpoint': 'SNEDH-001f6b0f-bb9e-4b81-956d-ceab7f87b13c'},
#   {'_id': '5cccf090e2705c193281f0ad',
#    'variables': ['_id',
#     'grupo-especifico',
#     'periodo',
#     'pob-ing-lbm-miles',
#     'pob-tot-miles',
#     'porc-pob-ing-lbm',
#     'date-insert'],
#    'count': 60,
#    'url': 'https://api.datos.gob.mx/v2/SNEDH-01319d5d-dbd8-4cd6-aa60-d5fb9d7e82a7',
#    'endpoint': 'SNEDH-01319d5d-dbd8-4cd6-aa60-d5fb9d7e82a7'},
#   {'_id': '5cccf090e2705c193281f0ae',
#    'variables': ['_id', 't', 'qet', 'qnt', 'pt', 'tqt', 'date-insert'],
#    'count': 7,
#    'url': 'https://api.datos.gob.mx/v2/SNEDH-074bea77-3dfa-4908-9930-65bef361b893',
#    'endpoint': 'SNEDH-074bea77-3dfa-4908-9930-65bef361b893'},
#   {'_id': '5cccf090e2705c193281f0af',
#    'variables': ['_id',
#     'cve-ent',
#     'entidad',
#     'periodo',
#     'pob-con-carencia-alim-miles',
#     'pob-tot-miles',
#     'porc-pob-carencia-alim',
#     'date-insert'],
#    'count': 132,
#    'url': 'https://api.datos.gob.mx/v2/SNEDH-07cdb67f-7303-462d-8ace-faa7bf947c16',
#    'endpoint': 'SNEDH-07cdb67f-7303-462d-8ace-faa7bf947c16'},
#   {'_id': '5cccf090e2705c193281f0b0',
#    'variables': ['_id',
#     'fecha',
#     'mujeres-extranjeras-beneficiadas-de-las-becas-otorgadas-por-la-amexcid',
#     'hombres-extranjeros-beneficiados-de-las-becas-otorgadas-por-la-amexcid',
#     'total-de-personas-beneficiadas-de-las-becas-otorgadas-por-la-amexcid',
#     'date-insert'],
#    'count': 5,
#    'url': 'https://api.datos.gob.mx/v2/SNEDH-0dd60e20-97a1-4644-8302-dade0bba59d4',
#    'endpoint': 'SNEDH-0dd60e20-97a1-4644-8302-dade0bba59d4'},
#   {'_id': '5cccf090e2705c193281f0b1',
#    'variables': ['_id',
#     'entidad-federativa',
#     'periodo',
#     'trimestre',
#     'trabajadores-subordinados-y-remunerados-con-afiliacion-sindical-total',
#     'total-de-trabajadores-subordinados-remunerados-total',
#     'date-insert'],
#    'count': 231,
#    'url': 'https://api.datos.gob.mx/v2/SNEDH-10084945-caa3-4ad2-b9e5-2927fedfa0f5',
#    'endpoint': 'SNEDH-10084945-caa3-4ad2-b9e5-2927fedfa0f5'},
#   {'_id': '5cccf090e2705c193281f0b2',
#    'variables': ['_id',
#     'programa',
#     'periodo',
#     'pef',
#     'pps',
#     'ppps',
#     'date-insert'],
#    'count': 32,
#    'url': 'https://api.datos.gob.mx/v2/SNEDH-10f94230-9164-4f14-add3-1a0ee9ea9b5f',
#    'endpoint': 'SNEDH-10f94230-9164-4f14-add3-1a0ee9ea9b5f'},
#   {'_id': '5cccf090e2705c193281f0b3',
#    'variables': ['_id',
#     'entidad-federativa',
#     'periodo',
#     'poblacion-de-15-anos-y-mas-total-poblacion-total',
#     'poblacion-alfabeta-de-15-anos-y-mas-poblacion-total',
#     'date-insert'],
#    'count': 66,
#    'url': 'https://api.datos.gob.mx/v2/SNEDH-1215991b-8bbf-4188-bf77-a0469ec2617e',
#    'endpoint': 'SNEDH-1215991b-8bbf-4188-bf77-a0469ec2617e'},
#   {'_id': '5cccf090e2705c193281f0b4',
#    'variables': ['_id',
#     'entidad-federativa',
#     'periodo',
#     'total-de-ocupantes-en-viviendas-particulares-habitadas',
#     'ocupantes-en-viviendas-particulares-habitadas-que-disponen-de-energia-electrica-total',
#     'date-insert'],
#    'count': 66,
#    'url': 'https://api.datos.gob.mx/v2/SNEDH-1c83fb04-1cdc-4ae3-b7a4-21d05f8c4065',
#    'endpoint': 'SNEDH-1c83fb04-1cdc-4ae3-b7a4-21d05f8c4065'},
#   {'_id': '5cccf090e2705c193281f0b5',
#    'variables': ['_id',
#     'periodo',
#     'gpfctit',
#     'gctit',
#     'pgpfctit',
#     'date-insert'],
#    'count': 7,
#    'url': 'https://api.datos.gob.mx/v2/SNEDH-1cd40277-c0e4-4248-b10f-6a49f79caa15',
#    'endpoint': 'SNEDH-1cd40277-c0e4-4248-b10f-6a49f79caa15'},
#   {'_id': '5cccf090e2705c193281f0b6',
#    'variables': ['_id',
#     'periodo',
#     'reclamaciones-y-quejas-por-actos-atribuidos-a-personas-servidoras-publicas-federales-y-o-poderes-publicos-federales',
#     'date-insert'],
#    'count': 6,
#    'url': 'https://api.datos.gob.mx/v2/SNEDH-1e4f9637-45ee-41e5-9d92-04dbc6a73120',
#    'endpoint': 'SNEDH-1e4f9637-45ee-41e5-9d92-04dbc6a73120'},
#   {'_id': '5cccf090e2705c193281f0b7',
#    'variables': ['_id',
#     'entidad-federativa',
#     'fecha',
#     'trimestre',
#     'poblacion-ocupada-total',
#     'poblacion-ocupada-de-15-a-19-anos-total',
#     'date-insert'],
#    'count': 231,
#    'url': 'https://api.datos.gob.mx/v2/SNEDH-201a6671-7287-44b4-911b-96b6d691708e',
#    'endpoint': 'SNEDH-201a6671-7287-44b4-911b-96b6d691708e'},
#   {'_id': '5cccf090e2705c193281f0b8',
#    'variables': ['_id',
#     'entidad-federativa',
#     'fecha',
#     'trimestre',
#     'poblacion-ocupada-con-una-percepcion-de-ingresos-por-su-actividad-inferior-a-dos-salarios-minimos-incluyendo-poblacion-ocupada-sin-ingresos-total',
#     'poblacion-ocupada-total',
#     'date-insert'],
#    'count': 231,
#    'url': 'https://api.datos.gob.mx/v2/SNEDH-23444004-ab72-42d4-9025-630a410c1f3c',
#    'endpoint': 'SNEDH-23444004-ab72-42d4-9025-630a410c1f3c'},
#   {'_id': '5cccf090e2705c193281f0b9',
#    'variables': ['_id',
#     'ocupantes-en-viviendas-particulares-habitadas-con-drenaje-conectado-a-red-publica-urbana',
#     'total-de-ocupantes-en-viviendas-particulares-habitadas-total',
#     'date-insert',
#     'ocupantes-en-viviendas-particulares-habitadas-con-drenaje-conectado-a-red-publica-rural',
#     'entidad-federativa',
#     'total-de-ocupantes-en-viviendas-particulares-habitadas-urbana',
#     'total-de-ocupantes-en-viviendas-particulares-habitadas-rural',
#     'periodo',
#     'ocupantes-en-viviendas-particulares-habitadas-con-drenaje-conectado-a-red-publica-total'],
#    'count': 66,
#    'url': 'https://api.datos.gob.mx/v2/SNEDH-23884293-8595-4b16-a7cf-09a269334a9c',
#    'endpoint': 'SNEDH-23884293-8595-4b16-a7cf-09a269334a9c'},
#   {'_id': '5cccf090e2705c193281f0ba',
#    'variables': ['_id', 'periodo', 'pefr14', 'pef', 'date-insert'],
#    'count': 8,
#    'url': 'https://api.datos.gob.mx/v2/SNEDH-23b19966-84bd-4b1b-8db0-03c11f144ccd',
#    'endpoint': 'SNEDH-23b19966-84bd-4b1b-8db0-03c11f144ccd'},
#   {'_id': '5cccf090e2705c193281f0bb',
#    'variables': ['_id',
#     'jurisdiccion-laboral',
#     'periodo',
#     'pef',
#     'pjl',
#     'date-insert'],
#    'count': 32,
#    'url': 'https://api.datos.gob.mx/v2/SNEDH-2492d96f-2c2f-4d5f-911a-71841b31e175',
#    'endpoint': 'SNEDH-2492d96f-2c2f-4d5f-911a-71841b31e175'},
#   {'_id': '5cccf090e2705c193281f0bc',
#    'variables': ['_id',
#     'fecha',
#     'proyectos-de-proteccion-ambiental-en-rencid',
#     'date-insert'],
#    'count': 4,
#    'url': 'https://api.datos.gob.mx/v2/SNEDH-270d33ad-b3f9-4ca6-815b-9809c61ed13b',
#    'endpoint': 'SNEDH-270d33ad-b3f9-4ca6-815b-9809c61ed13b'},
#   {'_id': '5cccf090e2705c193281f0bd',
#    'variables': ['_id',
#     'entidad-federativa',
#     'periodo',
#     'personas-de-12-anos-y-mas-de-edad-con-discapacidad-economicamente-activas-total',
#     'poblacion-de-12-anos-y-mas-con-discapacidad-total',
#     'date-insert'],
#    'count': 33,
#    'url': 'https://api.datos.gob.mx/v2/SNEDH-27d1ac47-dc05-4a14-8335-733a5bf783e0',
#    'endpoint': 'SNEDH-27d1ac47-dc05-4a14-8335-733a5bf783e0'},
#   {'_id': '5cccf090e2705c193281f0be',
#    'variables': ['_id',
#     'grupo-especifico',
#     'periodo',
#     'pob-ing-lbm-miles',
#     'pob-tot-miles',
#     'porc-pob-ing-lbm',
#     'date-insert'],
#    'count': 60,
#    'url': 'https://api.datos.gob.mx/v2/SNEDH-29b54f48-62cb-4b78-a025-4fe28550c070',
#    'endpoint': 'SNEDH-29b54f48-62cb-4b78-a025-4fe28550c070'},
#   {'_id': '5cccf090e2705c193281f0bf',
#    'variables': ['_id',
#     'entidad-federativa',
#     'periodo',
#     'cantidad-de-residuos-inorganicos-enviados-a-tratamiento-kg',
#     'total-de-material-recuperado-kg',
#     'date-insert'],
#    'count': 33,
#    'url': 'https://api.datos.gob.mx/v2/SNEDH-2aa92fe0-89fa-4bca-b813-fe4ead2a37b3',
#    'endpoint': 'SNEDH-2aa92fe0-89fa-4bca-b813-fe4ead2a37b3'},
#   {'_id': '5cccf090e2705c193281f0c0',
#    'variables': ['_id',
#     'cve-ent',
#     'entidad',
#     'periodo',
#     'consejos-ciudadanos',
#     'comisiones-estatales',
#     'date-insert'],
#    'count': 33,
#    'url': 'https://api.datos.gob.mx/v2/SNEDH-2aea684f-9869-4bc2-9fcc-572bf8e5f712',
#    'endpoint': 'SNEDH-2aea684f-9869-4bc2-9fcc-572bf8e5f712'},
#   {'_id': '5cccf090e2705c193281f0c1',
#    'variables': ['_id', 't', 'mst', 'tst', 'pms', 'date-insert'],
#    'count': 8,
#    'url': 'https://api.datos.gob.mx/v2/SNEDH-2cd860c4-6789-4d8e-8dfb-81c927c235de',
#    'endpoint': 'SNEDH-2cd860c4-6789-4d8e-8dfb-81c927c235de'},
#   {'_id': '5cccf090e2705c193281f0c2',
#    'variables': ['_id',
#     'cve-ent',
#     'entidad',
#     'periodo',
#     'pob-ing-lbm-miles',
#     'pob-tot-miles',
#     'porc-pob-ing-lbm',
#     'date-insert'],
#    'count': 132,
#    'url': 'https://api.datos.gob.mx/v2/SNEDH-2e97976c-b0c8-4bb1-be53-eab36fc7a149',
#    'endpoint': 'SNEDH-2e97976c-b0c8-4bb1-be53-eab36fc7a149'},
#   {'_id': '5cccf090e2705c193281f0c3',
#    'variables': ['_id', 'periodo', 'total-de-acciones', 'date-insert'],
#    'count': 4,
#    'url': 'https://api.datos.gob.mx/v2/SNEDH-306487e5-8085-40ea-b249-6390095ce03d',
#    'endpoint': 'SNEDH-306487e5-8085-40ea-b249-6390095ce03d'},
#   {'_id': '5cccf090e2705c193281f0c4',
#    'variables': ['_id',
#     'fecha',
#     'presentadas',
#     'rechazadas',
#     'admitidas-ordinarias',
#     'admitidas-extraordinarias',
#     'admitidas-totales',
#     'admitidas-totales-acumuladas',
#     'date-insert'],
#    'count': 7,
#    'url': 'https://api.datos.gob.mx/v2/SNEDH-31989aa7-2072-4b2c-9571-e24f239aaab4',
#    'endpoint': 'SNEDH-31989aa7-2072-4b2c-9571-e24f239aaab4'},
#   {'_id': '5cccf090e2705c193281f0c5',
#    'variables': ['_id', 'periodo', 'eco2t', 'pt', 'eco2per', 'date-insert'],
#    'count': 3,
#    'url': 'https://api.datos.gob.mx/v2/SNEDH-330f622e-bb02-472f-94f9-4c59910427cc',
#    'endpoint': 'SNEDH-330f622e-bb02-472f-94f9-4c59910427cc'},
#   {'_id': '5cccf090e2705c193281f0c6',
#    'variables': ['_id',
#     'periodo',
#     'entidad-federativa',
#     'solicitudes',
#     'date-insert'],
#    'count': 264,
#    'url': 'https://api.datos.gob.mx/v2/SNEDH-35e80c9f-cf4c-41d8-876a-3a8c87d1bb49',
#    'endpoint': 'SNEDH-35e80c9f-cf4c-41d8-876a-3a8c87d1bb49'},
#   {'_id': '5cccf090e2705c193281f0c7',
#    'variables': ['_id',
#     'entidad-federativa',
#     'periodo',
#     'deciles-de-hogares',
#     'gasto-corriente-promedio-trimestral-por-hogar-despues-del-gasto-en-necesidades-basicas-definidas-para-los-efectos-como-alimentacion-salud-electricidad-y-combustibles-en-el-primer-decil-de-la-poblacion-millones-de-pesos-a-precios-constantes-de-2008',
#     'date-insert'],
#    'count': 33,
#    'url': 'https://api.datos.gob.mx/v2/SNEDH-3743a98e-1699-435b-9b39-39675583d463',
#    'endpoint': 'SNEDH-3743a98e-1699-435b-9b39-39675583d463'},
#   {'_id': '5cccf090e2705c193281f0c8',
#    'variables': ['_id',
#     'cve-ent',
#     'entidad',
#     'periodo',
#     'oficinas-regionales',
#     'date-insert'],
#    'count': 33,
#    'url': 'https://api.datos.gob.mx/v2/SNEDH-39b6c71b-b12c-47b9-8bf5-bf160fa55b1e',
#    'endpoint': 'SNEDH-39b6c71b-b12c-47b9-8bf5-bf160fa55b1e'},
#   {'_id': '5cccf090e2705c193281f0c9',
#    'variables': ['_id', 'fecha', 'jrf', 'jc', 'pjrf', 'date-insert'],
#    'count': 8,
#    'url': 'https://api.datos.gob.mx/v2/SNEDH-3a89c399-ae7c-4c92-b5cb-0a2350e45b60',
#    'endpoint': 'SNEDH-3a89c399-ae7c-4c92-b5cb-0a2350e45b60'},
#   {'_id': '5cccf090e2705c193281f0ca',
#    'variables': ['_id',
#     'entidad-federativa',
#     'fecha',
#     'trimestre',
#     'poblacion-ocupada-total',
#     'poblacion-asalariada-no-incluye-al-personal-subordinado-remunerado-con-percepciones-no-salariales-15-anos-y-mas',
#     'porcentaje-de-trabajadores-asalariados-frente-al-total-de-ocupados',
#     '',
#     'date-insert'],
#    'count': 231,
#    'url': 'https://api.datos.gob.mx/v2/SNEDH-3cf060be-94ed-4dd8-be3d-0c4e0fe3d2e4',
#    'endpoint': 'SNEDH-3cf060be-94ed-4dd8-be3d-0c4e0fe3d2e4'},
#   {'_id': '5cccf090e2705c193281f0cb',
#    'variables': ['_id',
#     'fecha',
#     'inicios-ap-ci',
#     'determinaciones-ap',
#     'porcentaje',
#     'date-insert'],
#    'count': 7,
#    'url': 'https://api.datos.gob.mx/v2/SNEDH-3fefcd7b-e058-4360-b673-108b154aa468',
#    'endpoint': 'SNEDH-3fefcd7b-e058-4360-b673-108b154aa468'},
#   {'_id': '5cccf090e2705c193281f0cc',
#    'variables': ['_id',
#     'periodo',
#     'reclamaciones-y-quejas-por-actos-atribuidos-a-personas-servidoras-publicas-federales-y-o-poderes-publicos-federales',
#     'date-insert'],
#    'count': 6,
#    'url': 'https://api.datos.gob.mx/v2/SNEDH-427bd185-4131-4b4f-aa04-58e54addae2b',
#    'endpoint': 'SNEDH-427bd185-4131-4b4f-aa04-58e54addae2b'},
#   {'_id': '5cccf090e2705c193281f0cd',
#    'variables': ['_id', 'periodo', 'motivo', 'q', 'tq', 'pq', 'date-insert'],
#    'count': 138,
#    'url': 'https://api.datos.gob.mx/v2/SNEDH-4280ec21-ef75-48c3-b73c-9a587816fad9',
#    'endpoint': 'SNEDH-4280ec21-ef75-48c3-b73c-9a587816fad9'},
#   {'_id': '5cccf090e2705c193281f0ce',
#    'variables': ['_id', 'indicador-aar03', 'periodo', 'valor', 'date-insert'],
#    'count': 18,
#    'url': 'https://api.datos.gob.mx/v2/SNEDH-42f53e5c-fa41-47ce-9e42-1354253e462d',
#    'endpoint': 'SNEDH-42f53e5c-fa41-47ce-9e42-1354253e462d'},
#   {'_id': '5cccf090e2705c193281f0cf',
#    'variables': ['_id',
#     'entidad-federativa',
#     'fecha',
#     'trimestre',
#     'tasa-de-condiciones-criticas-de-ocupacion-total',
#     'date-insert'],
#    'count': 231,
#    'url': 'https://api.datos.gob.mx/v2/SNEDH-43519ebc-3d7b-4826-9a88-d3dff2837934',
#    'endpoint': 'SNEDH-43519ebc-3d7b-4826-9a88-d3dff2837934'},
#   {'_id': '5cccf090e2705c193281f0d0',
#    'variables': ['_id',
#     'periodo',
#     'eener',
#     'eind',
#     'eagr',
#     'edes',
#     'esilv',
#     'etotal',
#     'date-insert'],
#    'count': 1,
#    'url': 'https://api.datos.gob.mx/v2/SNEDH-45647f1e-3789-4231-be3f-b946908da1be',
#    'endpoint': 'SNEDH-45647f1e-3789-4231-be3f-b946908da1be'},
#   {'_id': '5cccf090e2705c193281f0d1',
#    'variables': ['_id',
#     'entidad-federativa',
#     'fecha',
#     'trimestre',
#     'tasa-de-informalidad-laboral-total',
#     'date-insert'],
#    'count': 231,
#    'url': 'https://api.datos.gob.mx/v2/SNEDH-45a64e4e-8932-45e0-8f35-f7046954c29f',
#    'endpoint': 'SNEDH-45a64e4e-8932-45e0-8f35-f7046954c29f'},
#   {'_id': '5cccf090e2705c193281f0d2',
#    'variables': ['_id',
#     'periodo',
#     'entidad-federativa',
#     'solicitudes',
#     'date-insert'],
#    'count': 264,
#    'url': 'https://api.datos.gob.mx/v2/SNEDH-45b750e8-8ddb-46cf-b822-358b120e10d0',
#    'endpoint': 'SNEDH-45b750e8-8ddb-46cf-b822-358b120e10d0'},
#   {'_id': '5cccf090e2705c193281f0d3',
#    'variables': ['_id',
#     'entidad-federativa',
#     'periodo',
#     'total-de-ocupantes-en-viviendas-particulares-habitadas',
#     'ocupantes-en-viviendas-particulares-habitadas-que-disponen-de-excusado-total',
#     'date-insert'],
#    'count': 66,
#    'url': 'https://api.datos.gob.mx/v2/SNEDH-48c1d767-cb71-48f0-a36a-2d937cf15c45',
#    'endpoint': 'SNEDH-48c1d767-cb71-48f0-a36a-2d937cf15c45'},
#   {'_id': '5cccf090e2705c193281f0d4',
#    'variables': ['_id',
#     'fecha',
#     'generacion-acumulada-desde-2004',
#     'date-insert'],
#    'count': 6,
#    'url': 'https://api.datos.gob.mx/v2/SNEDH-48d6069b-d30b-41e4-9e07-8c4d20a0d4c3',
#    'endpoint': 'SNEDH-48d6069b-d30b-41e4-9e07-8c4d20a0d4c3'},
#   {'_id': '5cccf090e2705c193281f0d5',
#    'variables': ['_id', 'periodo', 'motivo', 'q', 'tq', 'pq', 'date-insert'],
#    'count': 138,
#    'url': 'https://api.datos.gob.mx/v2/SNEDH-4924142d-9be8-47c1-8c78-379d941cd018',
#    'endpoint': 'SNEDH-4924142d-9be8-47c1-8c78-379d941cd018'},
#   {'_id': '5cccf090e2705c193281f0d6',
#    'variables': ['_id',
#     'delegacion',
#     'fecha',
#     'ap',
#     'ci',
#     'total',
#     'date-insert'],
#    'count': 238,
#    'url': 'https://api.datos.gob.mx/v2/SNEDH-4a28f010-cefc-4e53-8304-49ccad242a46',
#    'endpoint': 'SNEDH-4a28f010-cefc-4e53-8304-49ccad242a46'},
#   {'_id': '5cccf090e2705c193281f0d7',
#    'variables': ['_id',
#     'desagregacion',
#     'fecha',
#     'mt',
#     'pt',
#     'tmt',
#     'date-insert'],
#    'count': 264,
#    'url': 'https://api.datos.gob.mx/v2/SNEDH-4a82ab47-ece4-40fc-bf82-4a9fa23c2364',
#    'endpoint': 'SNEDH-4a82ab47-ece4-40fc-bf82-4a9fa23c2364'},
#   {'_id': '5cccf090e2705c193281f0d8',
#    'variables': ['pobt',
#     '_id',
#     'saotet',
#     'saombr',
#     'saoph',
#     'date-insert',
#     'saomcf',
#     'saohal',
#     'saocfc-13',
#     'saocfc',
#     'periodo',
#     'saohcfc'],
#    'count': 6,
#    'url': 'https://api.datos.gob.mx/v2/SNEDH-4a87a2a8-d845-412c-b04d-e4af5f56ca9d',
#    'endpoint': 'SNEDH-4a87a2a8-d845-412c-b04d-e4af5f56ca9d'},
#   {'_id': '5cccf090e2705c193281f0d9',
#    'variables': ['_id',
#     'cve-ent',
#     'entidad',
#     'periodo',
#     'ocup-viv-lenia-miles',
#     'pob-tot-miles',
#     'porc-ocup-viv-lenia',
#     'date-insert'],
#    'count': 132,
#    'url': 'https://api.datos.gob.mx/v2/SNEDH-4c1cbbb8-7f0f-4acb-96d6-5d28fa8d3415',
#    'endpoint': 'SNEDH-4c1cbbb8-7f0f-4acb-96d6-5d28fa8d3415'},
#   {'_id': '5cccf090e2705c193281f0da',
#    'variables': ['_id',
#     'entidad-federativa',
#     'deciles-de-hogares-1',
#     'periodo',
#     'gasto-corriente-monetario-trimestral-de-los-hogares-total-millones-de-pesos',
#     'gasto-corriente-monetario-trimestral-que-destinan-los-hogares-a-articulos-y-servicios-de-esparcimiento-millones-de-pesos',
#     'date-insert'],
#    'count': 33,
#    'url': 'https://api.datos.gob.mx/v2/SNEDH-4dce3d6e-297a-4aed-b883-030acb2d1e2a',
#    'endpoint': 'SNEDH-4dce3d6e-297a-4aed-b883-030acb2d1e2a'},
#   {'_id': '5cccf090e2705c193281f0db',
#    'variables': ['_id', 'periodo', 'pc', 'pcy', 'p', 'ppc', 'date-insert'],
#    'count': 1,
#    'url': 'https://api.datos.gob.mx/v2/SNEDH-4f5c2305-f7a5-4446-80bd-3772c236eade',
#    'endpoint': 'SNEDH-4f5c2305-f7a5-4446-80bd-3772c236eade'},
#   {'_id': '5cccf090e2705c193281f0dc',
#    'variables': ['_id',
#     'entidad-federativa',
#     'periodo',
#     'poblacion-que-se-considera-indigena-total',
#     'date-insert'],
#    'count': 2,
#    'url': 'https://api.datos.gob.mx/v2/SNEDH-4feed196-b153-461b-ba49-8a192031edb7',
#    'endpoint': 'SNEDH-4feed196-b153-461b-ba49-8a192031edb7'},
#   {'_id': '5cccf090e2705c193281f0dd',
#    'variables': ['_id', 'periodo', 'dpma', 'pob', 'tdpma', 'date-insert'],
#    'count': 7,
#    'url': 'https://api.datos.gob.mx/v2/SNEDH-5090591a-58b0-49e2-9f36-e865e8aa4b36',
#    'endpoint': 'SNEDH-5090591a-58b0-49e2-9f36-e865e8aa4b36'},
#   {'_id': '5cccf090e2705c193281f0de',
#    'variables': ['_id', 'variable', 'periodo', 'visitas', 'date-insert'],
#    'count': 7,
#    'url': 'https://api.datos.gob.mx/v2/SNEDH-53ed0dbb-4a46-468f-9442-7636b7a6d628',
#    'endpoint': 'SNEDH-53ed0dbb-4a46-468f-9442-7636b7a6d628'},
#   {'_id': '5cccf090e2705c193281f0df',
#    'variables': ['_id', 'periodo', 'total-de-ejemplares', 'date-insert'],
#    'count': 4,
#    'url': 'https://api.datos.gob.mx/v2/SNEDH-55dab076-19b0-4f6a-ae9b-2105b78366a6',
#    'endpoint': 'SNEDH-55dab076-19b0-4f6a-ae9b-2105b78366a6'},
#   {'_id': '5cccf090e2705c193281f0e0',
#    'variables': ['_id', 'periodo', 'festivales', 'date-insert'],
#    'count': 4,
#    'url': 'https://api.datos.gob.mx/v2/SNEDH-5613a682-1db4-4ab1-aba6-ab8a98992e68',
#    'endpoint': 'SNEDH-5613a682-1db4-4ab1-aba6-ab8a98992e68'},
#   {'_id': '5cccf090e2705c193281f0e1',
#    'variables': ['_id',
#     'periodo',
#     'solicitudes-anuales-de-informacion-inegi',
#     'date-insert'],
#    'count': 6,
#    'url': 'https://api.datos.gob.mx/v2/SNEDH-57ea9a79-4253-412c-ae21-ac8f9b55a825',
#    'endpoint': 'SNEDH-57ea9a79-4253-412c-ae21-ac8f9b55a825'},
#   {'_id': '5cccf090e2705c193281f0e2',
#    'variables': ['_id', 'periodo', 'ppec', 'pef', 'date-insert'],
#    'count': 8,
#    'url': 'https://api.datos.gob.mx/v2/SNEDH-59f33460-af6d-44c6-bf70-cfb04215d614',
#    'endpoint': 'SNEDH-59f33460-af6d-44c6-bf70-cfb04215d614'},
#   {'_id': '5cccf090e2705c193281f0e3',
#    'variables': ['_id',
#     'entidad-federativa',
#     'periodo',
#     'hogares-con-conexion-a-internet-porcentaje',
#     'hogares-con-conexion-a-internet-hogares',
#     'hogares-total',
#     'date-insert'],
#    'count': 66,
#    'url': 'https://api.datos.gob.mx/v2/SNEDH-5b8eb95e-a3d7-4ace-ab7a-ca4f13188e34',
#    'endpoint': 'SNEDH-5b8eb95e-a3d7-4ace-ab7a-ca4f13188e34'},
#   {'_id': '5cccf090e2705c193281f0e4',
#    'variables': ['_id', 't', 'psagarpa', 'pef', 'date-insert'],
#    'count': 8,
#    'url': 'https://api.datos.gob.mx/v2/SNEDH-5d19bcfa-88c2-4435-8f1f-22149c9a41cc',
#    'endpoint': 'SNEDH-5d19bcfa-88c2-4435-8f1f-22149c9a41cc'},
#   {'_id': '5cccf090e2705c193281f0e5',
#    'variables': ['_id', 'periodo', 'rst', 'pt', 'rspc', 'date-insert'],
#    'count': 3,
#    'url': 'https://api.datos.gob.mx/v2/SNEDH-5d21cce6-cd3d-4735-9752-c6e13ff6d0a1',
#    'endpoint': 'SNEDH-5d21cce6-cd3d-4735-9752-c6e13ff6d0a1'},
#   {'_id': '5cccf090e2705c193281f0e6',
#    'variables': ['_id',
#     'entidad-federativa',
#     'periodo',
#     'porcentaje-de-poblacion-con-acceso-sostenible-a-fuentes-mejoradas-de-abastecimiento-de-agua-total',
#     'total-de-ocupantes-en-viviendas-particulares-habitadas-a',
#     'ocupantes-en-viviendas-particulares-habitadas-con-agua-entubada-dentro-de-la-vivienda-o-el-predio',
#     'date-insert'],
#    'count': 66,
#    'url': 'https://api.datos.gob.mx/v2/SNEDH-5dc1b006-f7fa-44ac-912e-d2aadba63945',
#    'endpoint': 'SNEDH-5dc1b006-f7fa-44ac-912e-d2aadba63945'},
#   {'_id': '5cccf090e2705c193281f0e7',
#    'variables': ['_id',
#     'desagregacion',
#     'fecha',
#     'tt',
#     'pt',
#     'ttt',
#     'date-insert'],
#    'count': 264,
#    'url': 'https://api.datos.gob.mx/v2/SNEDH-5e4ba28a-6244-4cd1-8222-5f870ec5bce6',
#    'endpoint': 'SNEDH-5e4ba28a-6244-4cd1-8222-5f870ec5bce6'},
#   {'_id': '5cccf090e2705c193281f0e8',
#    'variables': ['_id',
#     'desagregacion',
#     'fecha',
#     'bt',
#     'pt',
#     'tbt',
#     'date-insert'],
#    'count': 264,
#    'url': 'https://api.datos.gob.mx/v2/SNEDH-604d4d60-77b3-4bb3-a1ed-9f45025f20e4',
#    'endpoint': 'SNEDH-604d4d60-77b3-4bb3-a1ed-9f45025f20e4'},
#   {'_id': '5cccf090e2705c193281f0e9',
#    'variables': ['_id',
#     'fase-primaria-otros-tipos',
#     'fase-primaria-selva-espinosa',
#     'fase-primaria-pastizal',
#     'fase-primaria-selva-perennifolia',
#     'date-insert',
#     'superficie-nacional',
#     'fase-primaria-bosques-de-coniferas',
#     'fase-primaria-bosque-mesofilo',
#     'fase-primaria-selva-subcaducifolia',
#     'fase-primaria-selva-caducifolia',
#     '',
#     'fase-primaria-vegetacion-hidrofila',
#     'fase-primaria-matorral-xerofilo',
#     'periodo',
#     'fase-primaria-bosque-de-encino'],
#    'count': 2,
#    'url': 'https://api.datos.gob.mx/v2/SNEDH-6291a1e2-3d72-431a-b6b6-32d03773b33a',
#    'endpoint': 'SNEDH-6291a1e2-3d72-431a-b6b6-32d03773b33a'},
#   {'_id': '5cccf090e2705c193281f0ea',
#    'variables': ['_id',
#     'entidad-federativa',
#     'periodo',
#     'vehiculos-de-motor-registrados-en-circulacion',
#     'poblacion-a-mitad-de-ano-personas',
#     'date-insert'],
#    'count': 6,
#    'url': 'https://api.datos.gob.mx/v2/SNEDH-634e91e3-4768-45ae-9a8e-b0bdce053a81',
#    'endpoint': 'SNEDH-634e91e3-4768-45ae-9a8e-b0bdce053a81'},
#   {'_id': '5cccf090e2705c193281f0eb',
#    'variables': ['_id', 'periodo', 'zmvm', 'date-insert'],
#    'count': 3,
#    'url': 'https://api.datos.gob.mx/v2/SNEDH-66fc7949-0be1-4c9c-8843-39451d7dda84',
#    'endpoint': 'SNEDH-66fc7949-0be1-4c9c-8843-39451d7dda84'},
#   {'_id': '5cccf090e2705c193281f0ec',
#    'variables': ['_id',
#     'ano-de-referencia',
#     'educandos-registrados-en-nivel-avanzado-secundaria-en-el-ano-t',
#     'numero-de-personas-mayores-de-15-anos-sin-secundaria-terminada-en-el-ano-t-1',
#     'porcentaje-de-cobertura-de-rezago-en-educacion-secundaria-en-el-ano-t',
#     'date-insert'],
#    'count': 8,
#    'url': 'https://api.datos.gob.mx/v2/SNEDH-671c7b28-a12d-412a-b8e4-672c1fbb36a1',
#    'endpoint': 'SNEDH-671c7b28-a12d-412a-b8e4-672c1fbb36a1'},
#   {'_id': '5cccf090e2705c193281f0ed',
#    'variables': ['_id', 'periodo', 'gide', 'pib', 'gp', 'date-insert'],
#    'count': 7,
#    'url': 'https://api.datos.gob.mx/v2/SNEDH-678bb367-ca3c-44d4-9365-5e821be00c9d',
#    'endpoint': 'SNEDH-678bb367-ca3c-44d4-9365-5e821be00c9d'},
#   {'_id': '5cccf090e2705c193281f0ee',
#    'variables': ['_id', 'periodo', 'ppsst', 'peframo14', 'date-insert'],
#    'count': 8,
#    'url': 'https://api.datos.gob.mx/v2/SNEDH-67a137f2-d914-46c2-9a2c-024f134715d0',
#    'endpoint': 'SNEDH-67a137f2-d914-46c2-9a2c-024f134715d0'},
#   {'_id': '5cccf090e2705c193281f0ef',
#    'variables': ['_id',
#     'institucion',
#     'periodo',
#     'pef',
#     'pfamb',
#     'date-insert'],
#    'count': 56,
#    'url': 'https://api.datos.gob.mx/v2/SNEDH-6b1a843f-c744-49ff-9ace-d06047a15692',
#    'endpoint': 'SNEDH-6b1a843f-c744-49ff-9ace-d06047a15692'},
#   {'_id': '5cccf090e2705c193281f0f0',
#    'variables': ['_id',
#     'entidad-federativa',
#     'periodo',
#     'volumen-de-la-poblacion-que-se-considera-afrodescendiente-miles-de-personas',
#     'date-insert'],
#    'count': 1,
#    'url': 'https://api.datos.gob.mx/v2/SNEDH-6f6e2809-9fed-4774-becd-dc53b5061cad',
#    'endpoint': 'SNEDH-6f6e2809-9fed-4774-becd-dc53b5061cad'},
#   {'_id': '5cccf090e2705c193281f0f1',
#    'variables': ['_id',
#     'periodo',
#     'gpfctit',
#     'gctit',
#     'pgpfctit',
#     'date-insert'],
#    'count': 7,
#    'url': 'https://api.datos.gob.mx/v2/SNEDH-71626ea2-8bbd-4ef3-888d-70f1d8613904',
#    'endpoint': 'SNEDH-71626ea2-8bbd-4ef3-888d-70f1d8613904'},
#   {'_id': '5cccf090e2705c193281f0f2',
#    'variables': ['_id',
#     'entidad-federativa',
#     'periodo',
#     'total-de-ocupantes-en-viviendas-particulares-habitadas',
#     'ocupantes-en-viviendas-particulares-habitadas-que-entregan-su-basura-a-servicios-de-recoleccion-total',
#     'date-insert'],
#    'count': 66,
#    'url': 'https://api.datos.gob.mx/v2/SNEDH-720b19c0-a12e-4f79-a329-eae19fabfe5f',
#    'endpoint': 'SNEDH-720b19c0-a12e-4f79-a329-eae19fabfe5f'},
#   {'_id': '5cccf090e2705c193281f0f3',
#    'variables': ['_id',
#     'fecha',
#     'circuito-judicial',
#     'entidad-federativa',
#     'tribunales-colegiados-de-circuito-con-competencia-en-materia-de-trabajo',
#     'poblacion-media-proyectada',
#     'indicador-tje01',
#     '',
#     'date-insert'],
#    'count': 256,
#    'url': 'https://api.datos.gob.mx/v2/SNEDH-72ed99f0-173d-43c9-b2b2-afe219076e20',
#    'endpoint': 'SNEDH-72ed99f0-173d-43c9-b2b2-afe219076e20'},
#   {'_id': '5cccf090e2705c193281f0f4',
#    'variables': ['_id', 'periodo', 'solicitudes', 'date-insert'],
#    'count': 6,
#    'url': 'https://api.datos.gob.mx/v2/SNEDH-75ab4c8d-0b1f-4697-ac6d-e682f6d40c94',
#    'endpoint': 'SNEDH-75ab4c8d-0b1f-4697-ac6d-e682f6d40c94'},
#   {'_id': '5cccf090e2705c193281f0f5',
#    'variables': ['_id',
#     'grupo',
#     'periodo',
#     'porcentaje-de-la-poblacion-alfabeta-de-18-anos-y-mas-que-leyo-por-lo-menos-un-libro-en-los-ultimos-12-meses',
#     'total-de-la-poblacion-alfabeta-de-18-anos-y-mas-que-leyo-por-lo-menos-un-libro-en-los-ultimos-12-meses',
#     'total-de-la-poblacion-alfabeta-de-18-anos-y-mas',
#     'date-insert'],
#    'count': 24,
#    'url': 'https://api.datos.gob.mx/v2/SNEDH-784df23d-71f4-47dd-b3bf-9f8cb12b1cf0',
#    'endpoint': 'SNEDH-784df23d-71f4-47dd-b3bf-9f8cb12b1cf0'},
#   {'_id': '5cccf090e2705c193281f0f6',
#    'variables': ['_id',
#     'entidad-federativa',
#     'fecha',
#     'trimestre',
#     'funcionarios-y-directivos-de-los-sectores-publico-privado-y-social-total',
#     'funcionarios-y-directivos-de-los-sectores-publico-privado-y-social-mujer',
#     'date-insert'],
#    'count': 264,
#    'url': 'https://api.datos.gob.mx/v2/SNEDH-794d12d2-7413-43d1-bd1f-56f6943e1a34',
#    'endpoint': 'SNEDH-794d12d2-7413-43d1-bd1f-56f6943e1a34'},
#   {'_id': '5cccf090e2705c193281f0f7',
#    'variables': ['_id',
#     'entidad-federativa',
#     'fecha',
#     'trimestre',
#     'poblacion-masculina-ocupada-total',
#     'poblacion-masculina-ocupada-con-prestaciones-laborales-total',
#     'date-insert'],
#    'count': 231,
#    'url': 'https://api.datos.gob.mx/v2/SNEDH-7a3592ee-7294-4960-93b4-9a2a07061daa',
#    'endpoint': 'SNEDH-7a3592ee-7294-4960-93b4-9a2a07061daa'},
#   {'_id': '5cccf090e2705c193281f0f8',
#    'variables': ['_id',
#     'ano-de-referencia',
#     'educandos-registrados-en-nivel-intermedio-primaria-en-el-ano-t',
#     'numero-de-personas-mayores-de-15-anos-sin-primaria-terminada-en-el-ano-t-1',
#     'porcentaje-de-cobertura-de-rezago-en-educacion-primaria-en-el-ano-t',
#     'date-insert'],
#    'count': 8,
#    'url': 'https://api.datos.gob.mx/v2/SNEDH-7c38adfb-a5bb-4824-9f93-4a2419a2058c',
#    'endpoint': 'SNEDH-7c38adfb-a5bb-4824-9f93-4a2419a2058c'},
#   {'_id': '5cccf090e2705c193281f0f9',
#    'variables': ['_id', 'fecha', 'crf', 'cc', 'pcrf', 'date-insert'],
#    'count': 8,
#    'url': 'https://api.datos.gob.mx/v2/SNEDH-81368820-18fa-4df0-a9f4-9fa56d296633',
#    'endpoint': 'SNEDH-81368820-18fa-4df0-a9f4-9fa56d296633'},
#   {'_id': '5cccf090e2705c193281f0fa',
#    'variables': ['_id',
#     'programa',
#     'periodo',
#     'pefcultura',
#     'papc',
#     'date-insert'],
#    'count': 18,
#    'url': 'https://api.datos.gob.mx/v2/SNEDH-84cf0b68-c6d8-4d39-8aeb-10b21a25e199',
#    'endpoint': 'SNEDH-84cf0b68-c6d8-4d39-8aeb-10b21a25e199'},
#   {'_id': '5cccf090e2705c193281f0fb',
#    'variables': ['_id',
#     'entidad-federativa',
#     'periodo',
#     'trimestre',
#     'ingreso-promedio-por-hora-trabajada-de-la-poblacion-ocupada-hombres',
#     'ingreso-promedio-por-hora-trabajada-de-la-poblacion-ocupada-mujeres',
#     'date-insert'],
#    'count': 3,
#    'url': 'https://api.datos.gob.mx/v2/SNEDH-866ec23c-b9b4-4f4b-88ce-fda80aabd600',
#    'endpoint': 'SNEDH-866ec23c-b9b4-4f4b-88ce-fda80aabd600'},
#   {'_id': '5cccf090e2705c193281f0fc',
#    'variables': ['_id',
#     'entidad-federativa',
#     'periodo',
#     'proporcion-de-mujeres-en-el-total-de-asalariados-en-el-sector-no-agropecuario',
#     'poblacion-ocupada-asalariada-de-15-anos-y-mas-en-el-sector-no-agropecuario',
#     'poblacion-ocupada-asalariada-femenina-de-15-anos-y-mas-en-el-sector-no-agropecuario',
#     'date-insert'],
#    'count': 264,
#    'url': 'https://api.datos.gob.mx/v2/SNEDH-873dd425-4c45-478a-a712-40ecb636d6c1',
#    'endpoint': 'SNEDH-873dd425-4c45-478a-a712-40ecb636d6c1'},
#   {'_id': '5cccf090e2705c193281f0fd',
#    'variables': ['_id',
#     'periodo',
#     'total-estimulos-apoyos-premios',
#     'date-insert'],
#    'count': 4,
#    'url': 'https://api.datos.gob.mx/v2/SNEDH-8a373549-1508-48da-99db-2505a085b7f4',
#    'endpoint': 'SNEDH-8a373549-1508-48da-99db-2505a085b7f4'},
#   {'_id': '5cccf090e2705c193281f0fe',
#    'variables': ['_id',
#     'grupo-especifico',
#     'periodo',
#     'ocup-viv-lenia-miles',
#     'pob-tot-miles',
#     'porc-ocup-viv-lenia',
#     'date-insert'],
#    'count': 60,
#    'url': 'https://api.datos.gob.mx/v2/SNEDH-8d9e07bd-7c3a-4968-86eb-866ee728c64e',
#    'endpoint': 'SNEDH-8d9e07bd-7c3a-4968-86eb-866ee728c64e'},
#   {'_id': '5cccf090e2705c193281f0ff',
#    'variables': ['_id',
#     'fecha',
#     'sexo',
#     'personas-defensoras-del-medio-ambiente-incorporadas',
#     'date-insert'],
#    'count': 21,
#    'url': 'https://api.datos.gob.mx/v2/SNEDH-8dbb8db5-d502-4910-9aef-4189c32ed92a',
#    'endpoint': 'SNEDH-8dbb8db5-d502-4910-9aef-4189c32ed92a'},
#   {'_id': '5cccf090e2705c193281f100',
#    'variables': ['_id',
#     'entidad-federativa',
#     'periodo',
#     'porcentaje-de-la-poblacion-de-18-anos-o-mas-que-habita-en-areas-de-100-mil-y-mas-habitantes-que-asistio-en-los-ultimos-doce-meses-a-un-concierto-o-presentacion-de-musica-en-vivo',
#     'porcentaje-de-la-poblacion-de-18-anos-o-mas-que-habita-en-areas-de-100-mil-y-mas-habitantes-que-asistio-en-los-ultimos-doce-meses-a-un-espectaculo-de-danza',
#     'porcentaje-de-la-poblacion-de-18-anos-o-mas-que-habita-en-areas-de-100-mil-y-mas-habitantes-que-asistio-en-los-ultimos-doce-meses-a-una-exposicion',
#     'porcentaje-de-la-poblacion-de-18-anos-o-mas-que-habita-en-areas-de-100-mil-y-mas-habitantes-que-asistio-en-los-ultimos-doce-meses-a-una-obra-de-teatro',
#     'porcentaje-de-la-poblacion-de-18-anos-o-mas-que-habita-en-areas-de-100-mil-y-mas-habitantes-que-asistio-en-los-ultimos-doce-meses-a-una-proyeccion-de-pelicula-o-cine',
#     'date-insert'],
#    'count': 1,
#    'url': 'https://api.datos.gob.mx/v2/SNEDH-8faed149-d432-4fef-8664-8eb2cf17b732',
#    'endpoint': 'SNEDH-8faed149-d432-4fef-8664-8eb2cf17b732'},
#   {'_id': '5cccf090e2705c193281f101',
#    'variables': ['_id', 'indicador-aar03', 'periodo', 'valor', 'date-insert'],
#    'count': 18,
#    'url': 'https://api.datos.gob.mx/v2/SNEDH-9309b49e-3517-4790-aeee-a9f430a69edf',
#    'endpoint': 'SNEDH-9309b49e-3517-4790-aeee-a9f430a69edf'},
#   {'_id': '5cccf090e2705c193281f102',
#    'variables': ['_id', 'periodo', 'oscactcult', 'date-insert'],
#    'count': 8,
#    'url': 'https://api.datos.gob.mx/v2/SNEDH-944c7e38-1d5a-4750-ae8b-e884f462ef17',
#    'endpoint': 'SNEDH-944c7e38-1d5a-4750-ae8b-e884f462ef17'},
#   {'_id': '5cccf090e2705c193281f103',
#    'variables': ['_id', 'periodo', 'ppae', 'pef', 'date-insert'],
#    'count': 8,
#    'url': 'https://api.datos.gob.mx/v2/SNEDH-950d0dd2-3795-47da-8f47-e0792857a68e',
#    'endpoint': 'SNEDH-950d0dd2-3795-47da-8f47-e0792857a68e'},
#   {'_id': '5cccf090e2705c193281f104',
#    'variables': ['_id',
#     'entidad-federativa',
#     'periodo',
#     'poblacion-de-3-anos-y-mas-hablante-de-lengua-indigena-total',
#     'date-insert'],
#    'count': 2,
#    'url': 'https://api.datos.gob.mx/v2/SNEDH-95a3fe13-a35e-48c3-8692-98317a4b67e1',
#    'endpoint': 'SNEDH-95a3fe13-a35e-48c3-8692-98317a4b67e1'},
#   {'_id': '5cccf090e2705c193281f105',
#    'variables': ['_id',
#     'cve-ent',
#     'entidad',
#     'periodo',
#     'ocup-viv-lenia-miles',
#     'pob-tot-miles',
#     'porc-ocup-viv-lenia',
#     'date-insert'],
#    'count': 132,
#    'url': 'https://api.datos.gob.mx/v2/SNEDH-97245744-cb5c-47af-9004-c8ce054f19fc',
#    'endpoint': 'SNEDH-97245744-cb5c-47af-9004-c8ce054f19fc'},
#   {'_id': '5cccf090e2705c193281f106',
#    'variables': ['_id',
#     'periodo',
#     'participacion-de-la-produccion-nacional-en-la-oferta-total-de-los-principales-granos-y-oleaginosas-maiz-trigo-frijol-arroz-sorgo-y-soya',
#     'date-insert'],
#    'count': 7,
#    'url': 'https://api.datos.gob.mx/v2/SNEDH-99cf58be-c0c6-40eb-8afa-e08286b29adc',
#    'endpoint': 'SNEDH-99cf58be-c0c6-40eb-8afa-e08286b29adc'},
#   {'_id': '5cccf090e2705c193281f107',
#    'variables': ['_id',
#     'entidad-federativa',
#     'periodo',
#     'trimestre',
#     'poblacion-de-5-a-17-anos-en-condicion-de-ocupacion-no-permitida',
#     'total-de-poblacion-de-5-a-17-anos-estimador-de-la-enoe',
#     'date-insert'],
#    'count': 3,
#    'url': 'https://api.datos.gob.mx/v2/SNEDH-9a52a2ad-6778-4894-b20f-844845126061',
#    'endpoint': 'SNEDH-9a52a2ad-6778-4894-b20f-844845126061'},
#   {'_id': '5cccf090e2705c193281f108',
#    'variables': ['_id',
#     'fecha',
#     'circuito-judicial',
#     'entidad-federativa',
#     'juzgados-de-distrito-con-competencia-en-materia-de-trabajo',
#     'poblacion-media-proyectada',
#     'indicador-tje02',
#     'date-insert'],
#    'count': 256,
#    'url': 'https://api.datos.gob.mx/v2/SNEDH-9b3194fa-4481-4456-97f8-26c0ea4183e9',
#    'endpoint': 'SNEDH-9b3194fa-4481-4456-97f8-26c0ea4183e9'},
#   {'_id': '5cccf090e2705c193281f109',
#    'variables': ['_id',
#     'periodo',
#     'visitas-total',
#     'visitas-diarias',
#     'date-insert'],
#    'count': 2,
#    'url': 'https://api.datos.gob.mx/v2/SNEDH-9bbeb41f-ac51-4628-a01e-33ab8bb09357',
#    'endpoint': 'SNEDH-9bbeb41f-ac51-4628-a01e-33ab8bb09357'},
#   {'_id': '5cccf090e2705c193281f10a',
#    'variables': ['_id',
#     'entidad-federativa',
#     'periodo',
#     'poblacion-que-habita-en-localidades-de-4999-habitantes-o-menos-total',
#     'poblacion-total-total',
#     'date-insert'],
#    'count': 33,
#    'url': 'https://api.datos.gob.mx/v2/SNEDH-9ca64f8a-8120-4ac6-b2ac-a52da57f837f',
#    'endpoint': 'SNEDH-9ca64f8a-8120-4ac6-b2ac-a52da57f837f'},
#   {'_id': '5cccf090e2705c193281f10b',
#    'variables': ['_id', 't', 'foc', 'fc', 'pfoc', 'date-insert'],
#    'count': 4,
#    'url': 'https://api.datos.gob.mx/v2/SNEDH-9cb4002c-f00d-4860-a6e7-6ad42ecd217d',
#    'endpoint': 'SNEDH-9cb4002c-f00d-4860-a6e7-6ad42ecd217d'},
#   {'_id': '5cccf090e2705c193281f10c',
#    'variables': ['_id',
#     'entidad-federativa',
#     'fecha',
#     'trimestre',
#     'poblacion-desocupada-total',
#     'poblacion-desocupada-por-duracion-del-desempleo-mas-de-1-ano-total',
#     'date-insert'],
#    'count': 231,
#    'url': 'https://api.datos.gob.mx/v2/SNEDH-9cb7a2a2-aff6-4796-a458-cc7aa47241da',
#    'endpoint': 'SNEDH-9cb7a2a2-aff6-4796-a458-cc7aa47241da'},
#   {'_id': '5cccf090e2705c193281f10d',
#    'variables': ['_id', 'desglose', 'ciclo-escolar', 'num-esc', 'date-insert'],
#    'count': 252,
#    'url': 'https://api.datos.gob.mx/v2/SNEDH-9e0cb023-3e34-4768-95a4-9d8512998033',
#    'endpoint': 'SNEDH-9e0cb023-3e34-4768-95a4-9d8512998033'}]}

# %% [markdown]
# ### Wikipedia API
#
# The MediaWiki Action API is a web service that allows access to some wiki-features like authentication, page operations, and search. It can provide meta information about the wiki and the logged-in user.
#
# - Data science
#     - From Wikipedia, the free encyclopedia
#
# https://en.wikipedia.org/wiki/Data_science#:~:text=Data%20science%20is%20an%20interdisciplinary,broad%20range%20of%20application%20domains.
#
# - EndPoint
#
# <https://www.mediawiki.org/wiki/API:Main_page>

# %%
# Import package
import requests

# Assign URL to variable: url
url = 'https://en.wikipedia.org/w/api.php?action=query&prop=extracts&format=json&exintro=&titles=data%20science'

# Package the request, send the request and catch the response: r
r = requests.get(url)

# Decode the JSON data into a dictionary: json_data
json_data = r.json()

#json_data

ds_data = json_data['query']['pages']['35458904']['extract']

print(ds_data)
# Out:
# <p class="mw-empty-elt">
# </p>
#
# <p><b>Data science</b> is an interdisciplinary field that uses scientific methods, processes, algorithms and systems to extract knowledge and insights from structured and unstructured data, and apply knowledge and actionable insights from data across a broad range of application domains. Data science is related to data mining, machine learning and big data.
# </p><p>Data science is a "concept to unify statistics, data analysis, informatics, and their related methods" in order to "understand and analyze actual phenomena" with data. It uses techniques and theories drawn from many fields within the context of mathematics, statistics, computer science, information science, and domain knowledge. However, data science is different from computer science and information science. Turing Award winner Jim Gray imagined data science as a "fourth paradigm" of science (empirical, theoretical, computational, and now data-driven) and asserted that "everything about science is changing because of the impact of information technology" and the data deluge.</p>

# %% [markdown]
# ## Working with relational databases in Python
#
# Relational databases, an essential element of any data scientist's toolkit.
#
# You will be learning about the relational model, creating SQL queries, filtering and ordering your SQL records, and advanced querying by JOINing database tables.

# %% [markdown]
# ### Creating a database engine
#
# - Chinook Database
#
#
# > The name of this sample database was based on the Northwind database. Chinooks are winds in the interior West of North America, where the Canadian Prairies and Great Plains meet various mountain ranges. Chinooks are most prevalent over southern Alberta in Canada. Chinook is a good name choice for a database that intends to be an alternative to Northwind.
#
# - DB
#
#     - <https://github.com/lerocha/chinook-database>
#
# - Engine
#
#     - <https://docs.sqlalchemy.org/en/14/core/engines.html>

# %%
# pip install sqlalchemy

# https://pypi.org/project/SQLAlchemy/

# https://docs.sqlalchemy.org/en/14/

# %%
# Import necessary module
from sqlalchemy import create_engine

# Create engine: engine
engine = create_engine('sqlite:///data/Chinook.sqlite')

print(engine)
# Out:
# Engine(sqlite:///data/Chinook.sqlite)

# %% [markdown]
# ### What are the tables in the database?
#
# Before you can get any data out of the database,  you'll need to know what tables it contains!
#
# To this end, you'll save the table names to a list using the method table_names() on the engine and then you will print the list.

# %%
# Save the table names to a list: table_names
table_names = engine.table_names()

# Print the table names to the shell
print(table_names)
# Out:
# ['Album', 'Artist', 'Customer', 'Employee', 'Genre', 'Invoice', 'InvoiceLine', 'MediaType', 'Playlist', 'PlaylistTrack', 'Track']

# %% [markdown]
# ![title](imgs/Chinook.png)

# %% [markdown]
# ### The Hello World of SQL Queries!
#
# In this section you'll perform the Hello World of SQL queries, SELECT, in order to retrieve all columns of the table Album in the Chinook database. Recall that the query SELECT * selects all columns.

# %%
# Import packages
from sqlalchemy import create_engine
import pandas as pd

# Create engine: engine
engine = create_engine('sqlite:///data/Chinook.sqlite')

# Open engine connection
con = engine.connect()

# Perform query: rs
rs = con.execute("SELECT * FROM Artist")

# Save results of the query to DataFrame: df
df = pd.DataFrame(rs.fetchall())

# Close connection
con.close()

# Print head of DataFrame df
df.head()
# Out:
#    0                  1
# 0  1              AC/DC
# 1  2             Accept
# 2  3          Aerosmith
# 3  4  Alanis Morissette
# 4  5    Alice In Chains

# %% [markdown]
# ## Importing from other formats

# %% [markdown]
# ### Importing SAS files
#
# - <https://www.sas.com/en_us/home.html>
#
# - <https://documentation.sas.com/doc/en/pgmsascdc/9.4_3.5/hostwin/n0sk6o15955yoen19n9ghdziqw1u.htm#p0sgui0b1o9nljn1crwkx9k7yr4w>

# %%
# !pip install sas7bdat

# Import sas7bdat package
from sas7bdat import SAS7BDAT

# Save file to a DataFrame: df_sas
with SAS7BDAT('data/sales.sas7bdat') as file:
    df_sas = file.to_data_frame()

# Print head of DataFrame
df_sas.head()

# %% [markdown]
# ### Importing Stata files
#
# <https://www.stata.com/>

# %%
# Import pandas
import pandas as pd

# Load Stata file into a pandas DataFrame: df
df = pd.read_stata('data/disarea.dta')

# Print the head of the DataFrame df
df.head()

# %% [markdown]
# ### Using h5py to import HDF5 files
#
# <https://www.hdfgroup.org/solutions/hdf5/>

# %%
# Import packages
import numpy as np
import h5py

# Assign filename: file
file = 'data/L-L1_LOSC_4_V1-1126259446-32.hdf5'

# Load file: data
data = h5py.File(file, 'r')

# Print the datatype of the loaded file
type(data)

# %%
# Print the keys of the file
for key in data.keys():
    print(key)

# %% [markdown]
# ### Loading MatLab (.mat) files
#
# <https://www.mathworks.com/products/matlab.html>

# %%
# Import package
import scipy.io

# Load MATLAB file: mat
mat = scipy.io.loadmat('data/albeck_gene_expression.mat ')
#mat = scipy.io.loadmat('data/ja_data2.mat')

# Print the datatype type of mat
print(type(mat))

# %%
# Print the keys of the MATLAB dictionary
mat.keys()

# %%
# Print the type of the value corresponding to the key 'CYratioCyt'
print(type(mat['CYratioCyt']))

# %%
# Print the shape of the value corresponding to the key 'CYratioCyt'
print(np.shape(mat['CYratioCyt']))

# %%
# Subset the array and plot it
data = mat['CYratioCyt'][25, 5:]

#data
